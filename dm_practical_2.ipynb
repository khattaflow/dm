# %%
import pandas as pd
import numpy as np
np.random.seed(0)
data={
    'age': np.random.randint(20, 57, size = 100),
    'income': np.random.randint(20000, 2000000, size = 100)
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     age   income
# 0    20   403570
# 1    23  1082830
# 2    23   858371
# 3    29  1551028
# 4    39  1105649
# ..  ...      ...
# 95   22  1870123
# 96   54   401094
# 97   55   624271
# 98   50   203645
# 99   23   245273
#
# [100 rows x 2 columns]

# %%
# df_standard = (df-df.mean())/df.std()
df_standard.std()
# Out:
# age       1.0
# income    1.0
# dtype: float64

# %%
df_normalize = (df-df.min())/(df.max()-df.min())
df_normalize
# Out:
#          age    income
# 0   0.000000  0.197575
# 1   0.083333  0.549212
# 2   0.083333  0.433015
# 3   0.250000  0.791588
# 4   0.527778  0.561025
# ..       ...       ...
# 95  0.055556  0.956776
# 96  0.944444  0.196293
# 97  0.972222  0.311827
# 98  0.833333  0.094078
# 99  0.083333  0.115628
#
# [100 rows x 2 columns]

# %%
df_transformed = df.copy()
df_transformed['income'] = np.log(df_transformed['income'])
df_transformed.head()
# Out:
#    age     income
# 0   20  12.908105
# 1   23  13.895089
# 2   23  13.662792
# 3   29  14.254428
# 4   39  13.915943

# %%
df_aggregated = df.groupby('age').mean().reset_index()
df_aggregated
# Out:
#     age        income
# 0    20  8.894021e+05
# 1    21  1.209645e+06
# 2    22  1.870123e+06
# 3    23  5.507232e+05
# 4    24  1.048190e+06
# 5    25  8.467242e+05
# 6    26  9.231390e+05
# 7    28  1.953619e+06
# 8    29  7.693408e+05
# 9    30  1.203052e+06
# 10   31  1.061786e+06
# 11   32  5.920347e+05
# 12   33  1.211249e+06
# 13   34  7.857393e+05
# 14   35  6.509252e+05
# 15   36  3.529820e+05
# 16   37  1.103918e+06
# 17   38  9.509010e+05
# 18   39  1.407559e+06
# 19   40  8.936687e+05
# 20   41  9.711050e+05
# 21   43  1.168997e+06
# 22   44  8.991422e+05
# 23   45  1.816107e+06
# 24   47  1.833078e+06
# 25   48  9.562320e+05
# 26   49  1.053728e+06
# 27   50  9.828975e+05
# 28   51  1.094055e+06
# 29   52  1.272880e+06
# 30   54  5.727408e+05
# 31   55  4.730170e+05
# 32   56  7.517850e+05

# %%
bins = [0,30,50,np.inf]
labels = ['Young', 'Adult', 'Elderly']
df_discretized = df.copy()
df_discretized['Age Group'] = pd.cut(df_discretized["age"], bins = bins, labels = labels)
df_discretized
# Out:
#     age   income Age Group
# 0    20   403570     Young
# 1    23  1082830     Young
# 2    23   858371     Young
# 3    29  1551028     Young
# 4    39  1105649     Adult
# ..  ...      ...       ...
# 95   22  1870123     Young
# 96   54   401094   Elderly
# 97   55   624271   Elderly
# 98   50   203645     Adult
# 99   23   245273     Young
#
# [100 rows x 3 columns]

# %%
from sklearn.preprocessing import Binarizer
threshold = 30
binarizer = Binarizer(threshold = threshold)
df_binarized = binarizer.fit_transform(df[['age']])
df_binarized = pd.DataFrame(df_binarized, columns=['Binarized_age'])
df_binarized = pd.concat([df, df_binarized], axis = 1)
print('Binarized dataset: ')
print(df_binarized.head())
# Out:
# Binarized dataset:
#    age   income  Binarized_age
# 0   20   403570              0
# 1   23  1082830              0
# 2   23   858371              0
# 3   29  1551028              0
# 4   39  1105649              1

# %%
df_sampled = df.sample(frac = 0.1, random_state = 1)
df_sampled
# Out:
#     age   income
# 80   51  1128731
# 84   56  1111871
# 33   21  1934136
# 81   25   665241
# 93   30   965590
# 17   33   264482
# 36   51   552574
# 82   50  1762150
# 69   34   692700
# 65   24  1685173
